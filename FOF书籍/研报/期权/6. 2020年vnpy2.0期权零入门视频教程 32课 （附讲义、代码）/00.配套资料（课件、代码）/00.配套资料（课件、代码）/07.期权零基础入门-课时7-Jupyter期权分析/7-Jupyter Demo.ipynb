# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(100))

# %%
def plot_call_price():
    k = 3000
    x = []
    y = []
    for s in range(2500, 3500, 100):
        p = max(s - k, 0)
        x.append(s)
        y.append(p)
    plt.plot(x, y)

plot_call_price()
